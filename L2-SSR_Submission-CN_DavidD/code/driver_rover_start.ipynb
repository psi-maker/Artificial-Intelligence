# %%
# %run drive_rover.py
# Out:
# NOT recording this run ...
# (11892) wsgi starting up on http://0.0.0.0:4567
# (11892) accepted ('127.0.0.1', 50928)
# connect  4a4930e7fa444dffa348b3af3ff1ae2f
# Current FPS: 1
# dict_keys(['position', 'samples_x', 'speed', 'steering_angle', 'samples_y', 'picking_up', 'yaw', 'brake', 'near_sample', 'pitch', 'throttle', 'sample_count', 'image', 'roll'])
# speed = 0.0 position = [99.67, 85.589] throttle = 0.0 steer_angle = 0.0 near_sample: 0 picking_up: 0 sending pickup: False total time: 0 samples remaining: 6 samples collected: 0
# Current FPS: 1
# dict_keys(['position', 'samples_x', 'speed', 'steering_angle', 'samples_y', 'picking_up', 'yaw', 'brake', 'near_sample', 'pitch', 'throttle', 'sample_count', 'image', 'roll'])
# speed = 0.0 position = [99.67, 85.589] throttle = 0.0 steer_angle = 0.0 near_sample: 0 picking_up: 0 sending pickup: False total time: 0.08836793899536133 samples remaining: 6 samples collected: 0
# Current FPS: 1
# ...
