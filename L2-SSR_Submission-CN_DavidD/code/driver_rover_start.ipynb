# %%
# %run drive_rover.py
# Out:
# NOT recording this run ...
# (1188) wsgi starting up on http://0.0.0.0:4567
# (1188) accepted ('127.0.0.1', 49918)
# connect  7696bccfdfc6460dbbda2e5880895b5b
# Current FPS: 1
# dict_keys(['near_sample', 'brake', 'speed', 'picking_up', 'sample_count', 'samples_x', 'position', 'roll', 'throttle', 'steering_angle', 'samples_y', 'yaw', 'image', 'pitch'])
# speed = 0.0 position = [99.67, 85.589] throttle = 0.0 steer_angle = 0.0 near_sample: 0 picking_up: 0 sending pickup: False total time: 0 samples remaining: 6 samples collected: 0
# Current FPS: 1
# dict_keys(['near_sample', 'brake', 'speed', 'picking_up', 'sample_count', 'samples_x', 'position', 'roll', 'throttle', 'steering_angle', 'samples_y', 'yaw', 'image', 'pitch'])
# speed = 0.0 position = [99.67, 85.589] throttle = 0.0 steer_angle = 0.0 near_sample: 0 picking_up: 0 sending pickup: False total time: 0.05805563926696777 samples remaining: 6 samples collected: 0
# Current FPS: 1
# ...
